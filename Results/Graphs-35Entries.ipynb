# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
x1=('medical students','other profiles')
y1=(7,28)
fig1=plt.bar(x1,y1,width=0.8,alpha=0.8,label='population',color='black',capsize=16)
plt.title('Population of the training',fontsize=18)
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14) 
plt.ylim(0,30)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
x2=('high-fidelity','other methods','not stated')
y2=(18,14,3)
fig2=plt.bar(x2,y2,width=0.8,alpha=0.8,label='Mannequin', color='black')
plt.title('Simulation methods used',fontsize=18)
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14) 
plt.ylim(0,30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
x7=('technical skills','non-technical skills','both', 'not stated')
y7=(18,2,8,7)
fig7=plt.bar(x7,y7,width=0.8,alpha=0.8,label='Context',color='brown')
plt.title('Type of skills trained')
plt.ylim(0,30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
x3=('yes','no','not stated')
y3=(2,29,4)
fig3=plt.bar(x3,y3,width=0.8,alpha=0.8,label='Automated Ev',color='green')
plt.title('Use of an automated evaluation process')
plt.ylim(0,30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
x4=('yes','no','not stated')
y4=(28,5,2)
fig4=plt.bar(x4,y4,width=0.8,alpha=0.8,label='Objective Ev',color='blue')
plt.title('Use of an objective evaluation process')
plt.ylim(0,30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
x5=('pre-hospital','in-hospital','pre and in-hospital')
y5=(4,25,5)
fig5=plt.bar(x5,y5,width=0.8,alpha=0.8,label='Context',color='black')
plt.title('Context in which the simulation focuses')
plt.ylim(0,30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Written Evaluation Forms/Checklists
Subjective Evaluation (interviews, written comments, evaluation of video performance, stating opinios/priorities once simulation 'is' done, direct observation)
Mixed
Others

# %%
x6=('checklists','subjective','mixed', 'not stated')
y6=(18,4,10,3)
fig6=plt.bar(x6,y6,width=0.8,alpha=0.8,label='Context',color='purple')
plt.title('Type of Evaluation')
plt.ylim(0,30)
plt.legend()
plt.tight_layout()
plt.show()
