# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x1=('yes','no')
y1=(7,27)
fig1=plt.bar(x1,y1,width=0.8,alpha=0.8,label='Students')
plt.title('Medical Students')
plt.legend()
plt.tight_layout()
plt.show()

# %%
x2=('yes','no','not stated')
y2=(17,14,3)
fig2=plt.bar(x2,y2,width=0.8,alpha=0.8,label='Mannequin', color='orange')
plt.title('Use of high fidelity mannequin')
plt.legend()
plt.tight_layout()
plt.show()

# %%
x3=('yes','no','not stated')
y3=(2,28,4)
fig3=plt.bar(x3,y3,width=0.8,alpha=0.8,label='Automated Ev',color='green')
plt.title('Use of an automated evaluation process')
plt.legend()
plt.tight_layout()
plt.show()

# %%
x4=('yes','no','not stated')
y4=(26,5,2)
fig4=plt.bar(x4,y4,width=0.8,alpha=0.8,label='Objective Ev',color='blue')
plt.title('Use of an objective evaluation process')
plt.legend()
plt.tight_layout()
plt.show()

# %%
x5=('pre-hospital','in-hospital','pre and in-hospital')
y5=(4,24,5)
fig5=plt.bar(x5,y5,width=0.8,alpha=0.8,label='Context',color='black')
plt.title('Context in which the simulation focuses')
plt.legend()
plt.tight_layout()
plt.show()
